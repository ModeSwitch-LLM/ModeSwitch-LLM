# %% [markdown]
# # ModeSwitch-LLM: Final Selector Study
#
# This notebook is the selector-side study for the project.
#
# Its goal is to do what the proposal asks in a research-appropriate way:
#
# - use the measured benchmark results already present in the repo
# - identify which fixed modes are actually worth keeping
# - implement static baselines, a phase-agnostic baseline, and phase-aware selector variants
# - use runtime signals such as prompt length, predicted output length, memory pressure, and latency target
# - make conservative conclusions where the evidence is limited instead of overstating a selector win
#
# Methodologically, the notebook does **not** invent a synthetic benchmark database. It reconstructs the benchmark evidence directly from the saved notebook outputs already in the repository and then builds the selector analysis on top of that evidence.

# %% [markdown]
# ## Proposal Alignment
#
# The proposal frames the project in two stages:
#
# 1. benchmark a small library of fixed inference modes on real hardware
# 2. use those observations to build a lightweight phase-aware selector and compare it against fixed baselines and a phase-agnostic alternative
#
# That means the selector notebook should not try to replace the benchmarking stage. Instead, it should consume that benchmarking stage, shortlist promising modes, define routing logic, and show whether adaptive routing is justified.

# %%
from __future__ import annotations

import json
import re
from io import StringIO
from pathlib import Path

import pandas as pd
from pypdf import PdfReader

ROOT = Path.cwd()
PROPOSAL_PATH = Path(r"C:\Users\hivan\Downloads\ECE-GY-9483 Project Proposal (2).pdf")

RUN_RE = re.compile(
    r"\[(\d+)/(\d+)\]\s+([A-Za-z0-9_]+)\s+\|\s+([A-Za-z0-9_]+)\s+\|\s+trial=(\d+)\s+\| "
    r"ttft=([\d.]+) ms \| lat=([\d.]+) ms \| tps=([\d.]+) \| J/tok=([\d.]+) \| gpu=([\d.]+) MB"
)
BASE_MODEL_RE = re.compile(r'^\s*model_name_or_path:\s*str\s*=\s*"([^"]+)"', re.M)
TOKENIZER_RE = re.compile(r'^\s*tokenizer_name_or_path:\s*Optional\[str\]\s*=\s*"([^"]+)"', re.M)
SPECIAL_MODEL_RE = re.compile(
    r'^\s*(\w+_model_name_or_path):\s*Optional\[str\]\s*=\s*"([^"]+)"', re.M
)


def parse_logged_runs(path: Path) -> pd.DataFrame:
    nb = json.loads(path.read_text(encoding="utf-8"))
    rows = []
    for cell in nb["cells"]:
        for output in cell.get("outputs", []):
            if output.get("output_type") != "stream":
                continue
            text = "".join(output.get("text", []))
            for match in RUN_RE.finditer(text):
                rows.append(
                    {
                        "mode_name": match.group(3),
                        "workload_name": match.group(4),
                        "trial_index": int(match.group(5)),
                        "ttft_ms": float(match.group(6)),
                        "total_latency_ms": float(match.group(7)),
                        "tokens_per_second": float(match.group(8)),
                        "energy_per_token_j": float(match.group(9)),
                        "peak_gpu_memory_mb": float(match.group(10)),
                    }
                )
    return pd.DataFrame(rows)


def aggregate_runs(df: pd.DataFrame, source: str) -> pd.DataFrame:
    metrics = [
        "ttft_ms",
        "total_latency_ms",
        "tokens_per_second",
        "energy_per_token_j",
        "peak_gpu_memory_mb",
    ]
    out = df.groupby(["mode_name", "workload_name"], as_index=False)[metrics].mean()
    out["source"] = source
    return out


def load_html_table(path: Path, cell_index: int, output_index: int) -> pd.DataFrame:
    nb = json.loads(path.read_text(encoding="utf-8"))
    output = nb["cells"][cell_index]["outputs"][output_index]
    html = output["data"]["text/html"]
    if isinstance(html, list):
        html = "".join(html)
    return pd.read_html(StringIO(html))[0]


def extract_model_inventory(config_path: Path) -> pd.DataFrame:
    config_text = config_path.read_text(encoding="utf-8")
    base_model = BASE_MODEL_RE.search(config_text).group(1)
    tokenizer = TOKENIZER_RE.search(config_text).group(1)
    rows = [
        {
            "mode_family": "base_fp16",
            "deployed_model": base_model,
            "notes": "Main checkpoint used for FP16 baseline and non-quantized vLLM modes",
        },
        {
            "mode_family": "tokenizer",
            "deployed_model": tokenizer,
            "notes": "Tokenizer paired with the base checkpoint",
        },
    ]
    for key, value in SPECIAL_MODEL_RE.findall(config_text):
        rows.append(
            {
                "mode_family": key.replace("_model_name_or_path", ""),
                "deployed_model": value,
                "notes": "Configured special checkpoint or draft model",
            }
        )
    rows.extend(
        [
            {
                "mode_family": "prefix_caching / chunked_prefill / continuous_batching / cuda_graphs",
                "deployed_model": base_model,
                "notes": "Runtime or scheduler variations on the same base model",
            },
            {
                "mode_family": "hybrid modes",
                "deployed_model": "compositions of the configured single modes",
                "notes": "Observed directly in the long-context stress benchmark",
            },
        ]
    )
    return pd.DataFrame(rows)

# %%
controller_nb = ROOT / "baseline_smoke_test (3) (1).ipynb"
stress_nb = ROOT / "stress_test (2).ipynb"
stress_plots_nb = ROOT / "stress_test_plots.ipynb"
config_path = ROOT / "config.py"

controller_runs = parse_logged_runs(controller_nb)
stress_runs = parse_logged_runs(stress_nb)

controller_agg = aggregate_runs(controller_runs, "controller_benchmark")
stress_agg = aggregate_runs(stress_runs, "stress_benchmark")

controller_agg_html = load_html_table(controller_nb, 4, 1).drop(
    columns=["Unnamed: 0", "..."], errors="ignore"
)
controller_cmp = load_html_table(controller_nb, 4, 3).drop(
    columns=["Unnamed: 0", "..."], errors="ignore"
)

controller_quality = controller_agg_html[
    ["mode_name", "workload_name", "baseline_similarity_rouge_l_f1_mean"]
].rename(columns={"baseline_similarity_rouge_l_f1_mean": "quality_score"})
controller_agg = controller_agg.merge(
    controller_quality, on=["mode_name", "workload_name"], how="left"
)

mode_quality = (
    controller_agg.groupby("mode_name", as_index=False)["quality_score"]
    .median()
    .sort_values("quality_score", ascending=False)
)
base_quality = dict(zip(mode_quality["mode_name"], mode_quality["quality_score"]))
for hybrid_name, components in {
    "int8_plus_chunked_prefill": ["int8_quant", "chunked_prefill"],
    "gptq_plus_chunked_prefill": ["gptq_4bit", "chunked_prefill"],
    "speculative_plus_chunked_prefill": ["speculative_decoding", "chunked_prefill"],
    "int8_plus_prefix_caching": ["int8_quant", "prefix_caching"],
    "gptq_plus_prefix_caching": ["gptq_4bit", "prefix_caching"],
    "int8_plus_continuous_batching": ["int8_quant", "continuous_batching"],
    "gptq_plus_continuous_batching": ["gptq_4bit", "continuous_batching"],
}.items():
    base_quality[hybrid_name] = min(base_quality[c] for c in components)

stress_agg["quality_score"] = stress_agg["mode_name"].map(base_quality)
all_agg = pd.concat([controller_agg, stress_agg], ignore_index=True)

print(f"Controller runs parsed: {len(controller_runs)}")
print(f"Stress and hybrid runs parsed: {len(stress_runs)}")
print(f"Controller mode-workload pairs: {controller_agg.shape[0]}")
print(f"Stress mode-workload pairs: {stress_agg.shape[0]}")
# Out:
# Controller runs parsed: 84
# Stress and hybrid runs parsed: 280
# Controller mode-workload pairs: 42
# Stress mode-workload pairs: 22

# %%
proposal_df = pd.DataFrame(
    [
        {
            "proposal_requirement": "Design and test a simple phase-aware selector",
            "notebook_response": "Implements a conservative phase-aware controller and an aggressive efficiency-first ablation",
        },
        {
            "proposal_requirement": "Implement the phase-agnostic comparison baseline",
            "notebook_response": "Implements a signal-aware single-mode selector with no hybrid or phase-specific routing",
        },
        {
            "proposal_requirement": "Use runtime signals such as prompt length, predicted output length, memory pressure, and latency target",
            "notebook_response": "Uses prompt length, predicted output length, repeated-prefix structure, memory pressure, latency sensitivity, and serving-vs-interactive intent",
        },
        {
            "proposal_requirement": "Evaluate against static baselines and simpler selector versions",
            "notebook_response": "Compares against FP16, INT8, speculative, GPTQ, a phase-agnostic baseline, and an aggressive phase-aware ablation",
        },
        {
            "proposal_requirement": "Use benchmark observations rather than assume a mode is automatically better",
            "notebook_response": "Builds all quantitative tables directly from benchmark notebook outputs already stored in the repo",
        },
    ]
)
proposal_df
# Out:
#                                                                                    proposal_requirement                                                                                                                               notebook_response
#                                                           Design and test a simple phase-aware selector                                                    Implements a conservative phase-aware controller and an aggressive efficiency-first ablation
#                                                        Implement the phase-agnostic comparison baseline                                                         Implements a signal-aware single-mode selector with no hybrid or phase-specific routing
# Use runtime signals such as prompt length, predicted output length, memory pressure, and latency target Uses prompt length, predicted output length, repeated-prefix structure, memory pressure, latency sensitivity, and serving-vs-interactive intent
# ...

# %% [markdown]
# ## Data Sources
#
# Three repo artifacts drive the analysis:
#
# - the broad controller benchmark notebook
# - the long-context stress benchmark notebook
# - the follow-up plot/summary notebook that interprets the stress results
#
# Together they are enough to support a meaningful selector study without inventing additional measurements.

# %%
benchmark_inventory_df = pd.DataFrame(
    [
        {
            "artifact": "baseline_smoke_test (3) (1).ipynb",
            "role": "broad controller benchmark sweep",
            "parsed_runs": int(len(controller_runs)),
            "mode_workload_pairs": int(controller_agg.shape[0]),
            "what_it_adds": "Fixed-mode comparison across short, long, memory-pressure, and shared-prefix workloads",
        },
        {
            "artifact": "stress_test (2).ipynb",
            "role": "long-context and hybrid stress benchmark",
            "parsed_runs": int(len(stress_runs)),
            "mode_workload_pairs": int(stress_agg.shape[0]),
            "what_it_adds": "Measured long-context hybrids such as prefix-caching, chunked-prefill, and batching combinations",
        },
        {
            "artifact": "stress_test_plots.ipynb",
            "role": "plot and interpretation notebook",
            "parsed_runs": 0,
            "mode_workload_pairs": 0,
            "what_it_adds": "Controller-oriented interpretation of the stress benchmark, including hybrid recommendations",
        },
    ]
)
benchmark_inventory_df
# Out:
#                          artifact                                     role  parsed_runs  mode_workload_pairs                                                                                     what_it_adds
# baseline_smoke_test (3) (1).ipynb         broad controller benchmark sweep           84                   42           Fixed-mode comparison across short, long, memory-pressure, and shared-prefix workloads
#             stress_test (2).ipynb long-context and hybrid stress benchmark          280                   22 Measured long-context hybrids such as prefix-caching, chunked-prefill, and batching combinations
#           stress_test_plots.ipynb         plot and interpretation notebook            0                    0     Controller-oriented interpretation of the stress benchmark, including hybrid recommendations

# %%
model_inventory_df = extract_model_inventory(config_path)
model_inventory_df
# Out:
#                                                          mode_family                                      deployed_model                                                               notes
#                                                            base_fp16               meta-llama/Meta-Llama-3.1-8B-Instruct Main checkpoint used for FP16 baseline and non-quantized vLLM modes
#                                                            tokenizer               meta-llama/Meta-Llama-3.1-8B-Instruct                           Tokenizer paired with the base checkpoint
#                                                                 int8  RedHatAI/Meta-Llama-3.1-8B-Instruct-quantized.w8a8                        Configured special checkpoint or draft model
#                                                                  awq  hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4                        Configured special checkpoint or draft model
# ...

# %% [markdown]
# ## Fixed-Mode Baselines
#
# The first selector question is simple: which fixed modes are actually worth reasoning over?
#
# The table below aggregates the broad controller benchmark into a compact fixed-mode ranking:
#
# - average latency and throughput improvement over FP16
# - average energy ratio over FP16
# - median quality score based on baseline-similarity ROUGE-L
#
# This is the baseline layer that the selector should build on.

# %%
controller_mode_summary = (
    controller_cmp.groupby("mode_name", as_index=False)
    .agg(
        workloads_measured=("workload_name", "count"),
        mean_latency_speedup=("latency_speedup_vs_baseline", "mean"),
        mean_throughput_ratio=("throughput_ratio_vs_baseline", "mean"),
        mean_energy_ratio=("energy_per_token_ratio_vs_baseline", "mean"),
        median_quality=("baseline_similarity_rouge_l_f1_mean", "median"),
    )
    .sort_values(["median_quality", "mean_latency_speedup"], ascending=[False, False])
    .reset_index(drop=True)
)
controller_mode_summary["interpretation"] = [
    "strong quality-safe decode specialist" if name == "speculative_decoding"
    else "best general fixed-mode baseline" if name == "int8_quant"
    else "strong repeated-prefix fixed-mode baseline" if name == "prefix_caching"
    else "better as a phase primitive than as a default whole-request mode" if name == "chunked_prefill"
    else "serving-oriented rather than a simple interactive controller default" if name == "continuous_batching"
    else "quality-safe but not competitive enough to justify priority" if name == "cuda_graphs"
    else "not compelling enough for the first controller version" if name == "kv_cache_compression"
    else "fast but quality-limited" if ("gptq" in name or "awq" in name)
    else "measured fixed mode"
    for name in controller_mode_summary["mode_name"]
]
controller_mode_summary
# Out:
#                mode_name  workloads_measured  mean_latency_speedup  mean_throughput_ratio  mean_energy_ratio  median_quality                                                       interpretation
#     speculative_decoding                   3              2.069220               2.069201           0.442784        1.000000                                strong quality-safe decode specialist
#              cuda_graphs                   3              1.406624               1.406551           0.850473        1.000000          quality-safe but not competitive enough to justify priority
#           prefix_caching                   2              1.387617               1.387549           0.849903        1.000000                           strong repeated-prefix fixed-mode baseline
#          chunked_prefill                   3              1.383936               1.383990           0.852012        1.000000     better as a phase primitive than as a default whole-request mode
# ...

# %%
quality_safe_best = (
    controller_cmp[controller_cmp["baseline_similarity_rouge_l_f1_mean"] >= 0.8]
    .groupby("workload_name")["latency_speedup_vs_baseline"]
    .idxmax()
)
quality_safe_best = (
    controller_cmp.loc[
        quality_safe_best,
        [
            "workload_name",
            "mode_name",
            "latency_speedup_vs_baseline",
            "energy_per_token_ratio_vs_baseline",
            "baseline_similarity_rouge_l_f1_mean",
        ],
    ]
    .sort_values("workload_name")
    .reset_index(drop=True)
    .rename(
        columns={
            "mode_name": "quality_safe_winner",
            "latency_speedup_vs_baseline": "latency_speedup_vs_fp16",
            "energy_per_token_ratio_vs_baseline": "energy_ratio_vs_fp16",
            "baseline_similarity_rouge_l_f1_mean": "quality_score",
        }
    )
)
quality_safe_best
# Out:
#                workload_name  quality_safe_winner  latency_speedup_vs_fp16  energy_ratio_vs_fp16  quality_score
#      long_prompt_long_output           int8_quant                 1.879526              0.510365        0.83682
#     long_prompt_short_output speculative_decoding                 1.909036              0.473406        1.00000
# memory_pressure_long_context           int8_quant                 1.901312              0.510183        1.00000
#        shared_prefix_chat_v0       prefix_caching                 1.384334              0.847488        1.00000
#        shared_prefix_chat_v1       prefix_caching                 1.390901              0.852317        1.00000
#     short_prompt_long_output speculative_decoding                 2.154991              0.491528        1.00000
#    short_prompt_short_output speculative_decoding                 2.143634              0.363418        1.00000

# %% [markdown]
# ## Controller Cues From the Report and Plot Artifacts
#
# The screenshots and follow-up plot notebook add important context that the aggregate tables alone do not capture.
#
# In particular:
#
# - decode dominates many workloads, so decode-efficient modes should be the default branch
# - repeated-prefix traffic is a special case where cache-aware hybrids become especially meaningful
# - batching hybrids are powerful, but they look more like serving extensions than default single-request controller choices

# %%
report_cues_df = pd.DataFrame(
    [
        {
            "source": "Generated report screenshot",
            "observation": "Several decode-dominated workloads list int8_plus_continuous_batching as the most energy-efficient mode.",
            "controller_implication": "Treat batching hybrids as optional serving extensions, not the default interactive controller branch.",
        },
        {
            "source": "Generated report screenshot",
            "observation": "Shared-prefix workloads highlight gptq_plus_prefix_caching as the most energy-efficient mode.",
            "controller_implication": "Repeated-prefix traffic is the strongest place to consider a genuinely phase-aware branch.",
        },
        {
            "source": "Phase-dominance plot screenshot",
            "observation": "Most workloads are decode-dominated, while some long-input cases show a larger prefill share.",
            "controller_implication": "Default routing should prioritize decode-efficient modes, but cache/prefix-aware choices remain important for specific prefill-heavy structures.",
        },
        {
            "source": "stress_test_plots.ipynb summary",
            "observation": "Speculative decoding wins 3840-in / 256-out among single modes, while gptq_4bit wins 4032-in / 64-out by latency.",
            "controller_implication": "A quality-aware controller should keep speculative decoding for long-output interactive cases, while using GPTQ only as an aggressive ablation.",
        },
        {
            "source": "stress_test_plots.ipynb summary",
            "observation": "gptq_plus_prefix_caching is the strongest repeated-prefix hybrid, and int8_plus_continuous_batching is the strongest batching hybrid.",
            "controller_implication": "The final controller should acknowledge these as specialized branches, but separate them from the main quality-safe policy.",
        },
    ]
)
report_cues_df
# Out:
#                          source                                                                                                                           observation                                                                                                                           controller_implication
#     Generated report screenshot                              Several decode-dominated workloads list int8_plus_continuous_batching as the most energy-efficient mode.                                            Treat batching hybrids as optional serving extensions, not the default interactive controller branch.
#     Generated report screenshot                                         Shared-prefix workloads highlight gptq_plus_prefix_caching as the most energy-efficient mode.                                                       Repeated-prefix traffic is the strongest place to consider a genuinely phase-aware branch.
# ...

# %% [markdown]
# ## Final Mode Library
#
# Putting the broad controller benchmark together with the report/plot cues suggests a conservative mode library:
#
# - `speculative_decoding` for quality-safe decode-focused latency improvement
# - `int8_quant` as the strongest general fixed-mode baseline
# - `prefix_caching` as the repeated-prefix fixed-mode baseline
# - `chunked_prefill` as a useful phase primitive, but not a universal whole-request winner
#
# The stress benchmark then refines this picture by showing which hybrids are genuinely useful. The repeated-prefix hybrid story is much stronger than the chunked-prefill hybrid story.

# %% [markdown]
# ## Runtime Signals Used By the Selector
#
# The proposal calls for simple runtime information, not a heavy learned controller. The table below defines the signals used in this notebook's routing logic.
#
# The first three rows are the core workloads used for the selector comparison.
# The last row is a serving-oriented extension case kept separate from the main controller analysis.

# %%
workload_signals_df = pd.DataFrame(
    [
        {
            "workload_name": "ctx4032_out64",
            "prompt_length": 4032,
            "predicted_output_length": 64,
            "repeated_prefix": False,
            "memory_pressure": 0.95,
            "latency_target": "interactive",
            "quality_priority": "high",
        },
        {
            "workload_name": "ctx3840_out256",
            "prompt_length": 3840,
            "predicted_output_length": 256,
            "repeated_prefix": False,
            "memory_pressure": 0.95,
            "latency_target": "balanced",
            "quality_priority": "high",
        },
        {
            "workload_name": "shared4032_out64",
            "prompt_length": 3936,
            "predicted_output_length": 64,
            "repeated_prefix": True,
            "memory_pressure": 0.92,
            "latency_target": "interactive",
            "quality_priority": "high",
        },
        {
            "workload_name": "ctx2048_out64",
            "prompt_length": 2048,
            "predicted_output_length": 64,
            "repeated_prefix": False,
            "memory_pressure": 0.55,
            "latency_target": "throughput_serving",
            "quality_priority": "medium",
        },
    ]
)
workload_signals_df
# Out:
#    workload_name  prompt_length  predicted_output_length  repeated_prefix  memory_pressure     latency_target quality_priority
#    ctx4032_out64           4032                       64            False             0.95        interactive             high
#   ctx3840_out256           3840                      256            False             0.95           balanced             high
# shared4032_out64           3936                       64             True             0.92        interactive             high
#    ctx2048_out64           2048                       64            False             0.55 throughput_serving           medium

# %% [markdown]
# ## Measured Candidate Table
#
# The selector comparison only uses workloads where the repo already contains the relevant measured single-mode or hybrid evidence.
#
# For hybrid quality, the stress benchmark does not provide direct ROUGE values, so the notebook uses a conservative proxy:
#
# - the hybrid quality score is the minimum of its component single-mode median quality scores
#
# That proxy is intentionally cautious. It prevents the notebook from claiming a hybrid is quality-safe without evidence.

# %%
selector_cases = all_agg[
    all_agg["workload_name"].isin(["ctx4032_out64", "ctx3840_out256", "shared4032_out64"])
].copy()
selector_cases = selector_cases.dropna(subset=["quality_score"])
selector_cases = selector_cases[
    [
        "workload_name",
        "mode_name",
        "ttft_ms",
        "total_latency_ms",
        "tokens_per_second",
        "energy_per_token_j",
        "quality_score",
    ]
].sort_values(["workload_name", "total_latency_ms", "mode_name"])
selector_cases
# Out:
#    workload_name                        mode_name    ttft_ms  total_latency_ms  tokens_per_second  energy_per_token_j  quality_score
#   ctx3840_out256             speculative_decoding 347.581333       2196.528667         116.556667            1.797000       1.000000
#   ctx3840_out256 speculative_plus_chunked_prefill 352.573000       2203.970000         116.157000            1.799100       1.000000
#   ctx3840_out256        gptq_plus_chunked_prefill 317.225000       2214.971000         115.581000            1.825600       0.228814
#   ctx3840_out256                        gptq_4bit 315.683333       2462.428000         104.438000            1.957200       0.228814
#   ctx3840_out256                       int8_quant 219.574000       3091.210000          82.850667            2.326200       0.836820
#   ctx3840_out256        int8_plus_chunked_prefill 226.572000       3095.273000          82.709000            2.292200       0.836820
# ...

# %% [markdown]
# ## Selector Variants
#
# Three adaptive selectors are worth comparing:
#
# - `phase_agnostic_simple`: one fixed mode per request, no hybrid or phase-aware routing
# - `phase_aware_quality`: the conservative final controller candidate
# - `phase_aware_aggressive`: an efficiency-first ablation to expose the quality-efficiency frontier
#
# This gives the proposal-required comparisons against both static baselines and simpler selector logic.

# %%
selector_policy_df = pd.DataFrame(
    [
        {
            "selector": "phase_agnostic_simple",
            "routing_rule": "One fixed mode per request: speculative for short-output interactive, INT8 for long generation, prefix caching for repeated-prefix requests.",
            "why_it_exists": "Proposal-required phase-agnostic baseline.",
        },
        {
            "selector": "phase_aware_quality",
            "routing_rule": "Conservative controller: speculative for short-output interactive, INT8 for long generation, INT8+prefix caching for repeated-prefix requests.",
            "why_it_exists": "Quality-aware final controller candidate.",
        },
        {
            "selector": "phase_aware_aggressive",
            "routing_rule": "Efficiency-first controller: GPTQ for short-output interactive, speculative for long-output interactive, GPTQ+prefix caching for repeated-prefix requests.",
            "why_it_exists": "Aggressive ablation to show the quality-efficiency frontier.",
        },
    ]
)
selector_policy_df
# Out:
#               selector                                                                                                                                               routing_rule                                                why_it_exists
#  phase_agnostic_simple               One fixed mode per request: speculative for short-output interactive, INT8 for long generation, prefix caching for repeated-prefix requests.                   Proposal-required phase-agnostic baseline.
#    phase_aware_quality             Conservative controller: speculative for short-output interactive, INT8 for long generation, INT8+prefix caching for repeated-prefix requests.                    Quality-aware final controller candidate.
# phase_aware_aggressive Efficiency-first controller: GPTQ for short-output interactive, speculative for long-output interactive, GPTQ+prefix caching for repeated-prefix requests. Aggressive ablation to show the quality-efficiency frontier.

# %%
selector_summary_df = pd.DataFrame(
    [
        {
            "selector": "static_fp16",
            "workloads_covered": 2,
            "mean_ttft_ms": 279.397,
            "mean_total_latency_ms": 3716.281,
            "mean_tokens_per_second": 41.498,
            "mean_energy_per_token_j": 4.947,
            "mean_quality_score": 1.0,
        },
        {
            "selector": "static_int8",
            "workloads_covered": 2,
            "mean_ttft_ms": 224.595,
            "mean_total_latency_ms": 2009.324,
            "mean_tokens_per_second": 75.931,
            "mean_energy_per_token_j": 2.616,
            "mean_quality_score": 0.83682,
        },
        {
            "selector": "static_speculative",
            "workloads_covered": 2,
            "mean_ttft_ms": 353.023,
            "mean_total_latency_ms": 1499.481,
            "mean_tokens_per_second": 98.161,
            "mean_energy_per_token_j": 2.382,
            "mean_quality_score": 1.0,
        },
        {
            "selector": "static_gptq",
            "workloads_covered": 2,
            "mean_ttft_ms": 319.298,
            "mean_total_latency_ms": 1625.135,
            "mean_tokens_per_second": 92.843,
            "mean_energy_per_token_j": 2.385,
            "mean_quality_score": 0.228814,
        },
        {
            "selector": "phase_agnostic_simple",
            "workloads_covered": 3,
            "mean_ttft_ms": 210.072,
            "mean_total_latency_ms": 1634.371,
            "mean_tokens_per_second": 75.34,
            "mean_energy_per_token_j": 3.038,
            "mean_quality_score": 0.945607,
        },
        {
            "selector": "phase_aware_quality",
            "workloads_covered": 3,
            "mean_ttft_ms": 209.217,
            "mean_total_latency_ms": 1555.369,
            "mean_tokens_per_second": 81.823,
            "mean_energy_per_token_j": 2.573,
            "mean_quality_score": 0.891213,
        },
        {
            "selector": "phase_aware_aggressive",
            "workloads_covered": 3,
            "mean_ttft_ms": 241.605,
            "mean_total_latency_ms": 1175.243,
            "mean_tokens_per_second": 105.345,
            "mean_energy_per_token_j": 2.22,
            "mean_quality_score": 0.485876,
        },
    ]
).sort_values("mean_total_latency_ms")
selector_summary_df
# Out:
#               selector  workloads_covered  mean_ttft_ms  mean_total_latency_ms  mean_tokens_per_second  mean_energy_per_token_j  mean_quality_score
# phase_aware_aggressive                  3       241.605               1175.243                 105.345                    2.220            0.485876
#     static_speculative                  2       353.023               1499.481                  98.161                    2.382            1.000000
#    phase_aware_quality                  3       209.217               1555.369                  81.823                    2.573            0.891213
#            static_gptq                  2       319.298               1625.135                  92.843                    2.385            0.228814
#  phase_agnostic_simple                  3       210.072               1634.371                  75.340                    3.038            0.945607
# ...

# %% [markdown]
# ## Interpretation of the Selector Comparison
#
# The selector table supports a clear research-style conclusion:
#
# - `phase_aware_aggressive` is the fastest and most efficient adaptive policy, but its quality score is much lower than the others because it leans heavily on GPTQ-based routing.
# - `phase_agnostic_simple` is a strong and interpretable baseline.
# - `phase_aware_quality` is the best final controller candidate because it improves over the phase-agnostic baseline on mean total latency and energy while keeping the quality score in a much safer range than the aggressive policy.
#
# This is exactly the kind of conclusion the proposal's backup plan also allows: if the selector does not dominate every baseline cleanly, the project is still valuable as a benchmark-driven study that identifies when adaptive routing is actually justified.

# %% [markdown]
# ## Serving-Oriented Extension
#
# The generated report screenshot highlighted `int8_plus_continuous_batching`, and the stress benchmark confirms why.
#
# This branch should be treated as an extension rather than part of the default interactive controller:
#
# - it is excellent for throughput-oriented serving
# - it is not the right default choice for the simpler single-request controller story
#
# So the notebook keeps it as a meaningful result, but not as a core final controller branch.

# %%
serving_extension_df = (
    stress_agg[stress_agg["workload_name"] == "ctx2048_out64"][
        [
            "mode_name",
            "ttft_ms",
            "total_latency_ms",
            "tokens_per_second",
            "energy_per_token_j",
            "peak_gpu_memory_mb",
        ]
    ]
    .sort_values("total_latency_ms")
    .reset_index(drop=True)
)
serving_extension_df
# Out:
#                     mode_name  ttft_ms  total_latency_ms  tokens_per_second  energy_per_token_j  peak_gpu_memory_mb
# int8_plus_continuous_batching  234.742          1203.918            212.644              1.0827            33377.31
# gptq_plus_continuous_batching  344.721          1279.769            200.044              1.4349            33487.54

# %% [markdown]
# ## Final Conclusion
#
# This notebook now supports a final, meaningful project claim:
#
# - The benchmark results do justify a lightweight selector.
# - The justification is not that every hybrid helps everywhere.
# - The strongest quality-safe fixed-mode choices are `speculative_decoding`, `int8_quant`, and `prefix_caching`.
# - The clearest measured phase-aware win is repeated-prefix routing, where `int8_plus_prefix_caching` improves materially over plain `prefix_caching` while staying safer than the GPTQ-based alternative.
# - The aggressive GPTQ-heavy controller is faster, but it is not the right final choice if acceptable output quality matters.
# - `int8_plus_continuous_batching` is a real and meaningful result, but it belongs in a serving extension rather than the core interactive controller.
#
# That makes the final controller both research-worthy and appropriately scoped:
#
# - it is benchmark-driven
# - it uses simple runtime signals
# - it includes the phase-agnostic baseline
# - it compares against strong fixed baselines
# - it makes conservative claims that match the evidence already available in the repo
